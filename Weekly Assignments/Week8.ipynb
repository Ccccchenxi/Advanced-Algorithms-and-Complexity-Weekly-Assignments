# %% [markdown]
# ## Assignment 1

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
mushroom = fetch_ucirepo(id=73) 
  
# data (as pandas dataframes) 
X = mushroom.data.features 
y = mushroom.data.targets 
  
# metadata 
print(mushroom.metadata) 
  
# variable information 
print(mushroom.variables)
# Out:
# {'uci_id': 73, 'name': 'Mushroom', 'repository_url': 'https://archive.ics.uci.edu/dataset/73/mushroom', 'data_url': 'https://archive.ics.uci.edu/static/public/73/data.csv', 'abstract': 'From Audobon Society Field Guide; mushrooms described in terms of physical characteristics; classification: poisonous or edible', 'area': 'Biology', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 8124, 'num_features': 22, 'feature_types': ['Categorical'], 'demographics': [], 'target_col': ['poisonous'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1981, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5959T', 'creators': [], 'intro_paper': None, 'additional_info': {'summary': "This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family (pp. 500-525).  Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended.  This latter class was combined with the poisonous one.  The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like ``leaflets three, let it be'' for Poisonous Oak and Ivy.", 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': '     1. cap-shape:                bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s\r\n     2. cap-surface:              fibrous=f,grooves=g,scaly=y,smooth=s\r\n     3. cap-color:                brown=n,buff=b,cinnamon=c,gray=g,green=r, pink=p,purple=u,red=e,white=w,yellow=y\r\n     4. bruises?:                 bruises=t,no=f\r\n     5. odor:                     almond=a,anise=l,creosote=c,fishy=y,foul=f, musty=m,none=n,pungent=p,spicy=s\r\n     6. gill-attachment:          attached=a,descending=d,free=f,notched=n\r\n     7. gill-spacing:             close=c,crowded=w,distant=d\r\n     8. gill-size:                broad=b,narrow=n\r\n     9. gill-color:               black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e, white=w,yellow=y\r\n    10. stalk-shape:              enlarging=e,tapering=t\r\n    11. stalk-root:               bulbous=b,club=c,cup=u,equal=e, rhizomorphs=z,rooted=r,missing=?\r\n    12. stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s\r\n    13. stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s\r\n    14. stalk-color-above-ring:   brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y\r\n    15. stalk-color-below-ring:   brown=n,buff=b,cinnamon=c,gray=g,orange=o, pink=p,red=e,white=w,yellow=y\r\n    16. veil-type:                partial=p,universal=u\r\n    17. veil-color:               brown=n,orange=o,white=w,yellow=y\r\n    18. ring-number:              none=n,one=o,two=t\r\n    19. ring-type:                cobwebby=c,evanescent=e,flaring=f,large=l, none=n,pendant=p,sheathing=s,zone=z\r\n    20. spore-print-color:        black=k,brown=n,buff=b,chocolate=h,green=r, orange=o,purple=u,white=w,yellow=y\r\n    21. population:               abundant=a,clustered=c,numerous=n, scattered=s,several=v,solitary=y\r\n    22. habitat:                  grasses=g,leaves=l,meadows=m,paths=p, urban=u,waste=w,woods=d', 'citation': None}}
#                         name     role         type demographic  \
# 0                  poisonous   Target  Categorical        None
# 1                  cap-shape  Feature  Categorical        None
# 2                cap-surface  Feature  Categorical        None
# 3                  cap-color  Feature       Binary        None
# 4                    bruises  Feature  Categorical        None
# 5                       odor  Feature  Categorical        None
# 6            gill-attachment  Feature  Categorical        None
# 7               gill-spacing  Feature  Categorical        None
# 8                  gill-size  Feature  Categorical        None
# 9                 gill-color  Feature  Categorical        None
# 10               stalk-shape  Feature  Categorical        None
# 11                stalk-root  Feature  Categorical        None
# 12  stalk-surface-above-ring  Feature  Categorical        None
# 13  stalk-surface-below-ring  Feature  Categorical        None
# 14    stalk-color-above-ring  Feature  Categorical        None
# 15    stalk-color-below-ring  Feature  Categorical        None
# 16                 veil-type  Feature       Binary        None
# 17                veil-color  Feature  Categorical        None
# 18               ring-number  Feature  Categorical        None
# 19                 ring-type  Feature  Categorical        None
# 20         spore-print-color  Feature  Categorical        None
# 21                population  Feature  Categorical        None
# 22                   habitat  Feature  Categorical        None
#
#                                           description units missing_values
# 0                                                None  None             no
# 1   bell=b,conical=c,convex=x,flat=f, knobbed=k,su...  None             no
# 2                fibrous=f,grooves=g,scaly=y,smooth=s  None             no
# 3   brown=n,buff=b,cinnamon=c,gray=g,green=r, pink...  None             no
# 4                                      bruises=t,no=f  None             no
# 5   almond=a,anise=l,creosote=c,fishy=y,foul=f, mu...  None             no
# 6            attached=a,descending=d,free=f,notched=n  None             no
# 7                         close=c,crowded=w,distant=d  None             no
# 8                                    broad=b,narrow=n  None             no
# 9   black=k,brown=n,buff=b,chocolate=h,gray=g, gre...  None             no
# 10                             enlarging=e,tapering=t  None             no
# 11  bulbous=b,club=c,cup=u,equal=e, rhizomorphs=z,...  None            yes
# 12                 fibrous=f,scaly=y,silky=k,smooth=s  None             no
# 13                 fibrous=f,scaly=y,silky=k,smooth=s  None             no
# 14  brown=n,buff=b,cinnamon=c,gray=g,orange=o, pin...  None             no
# 15  brown=n,buff=b,cinnamon=c,gray=g,orange=o, pin...  None             no
# 16                              partial=p,universal=u  None             no
# 17                  brown=n,orange=o,white=w,yellow=y  None             no
# 18                                 none=n,one=o,two=t  None             no
# 19  cobwebby=c,evanescent=e,flaring=f,large=l, non...  None             no
# 20  black=k,brown=n,buff=b,chocolate=h,green=r, or...  None             no
# 21  abundant=a,clustered=c,numerous=n, scattered=s...  None             no
# 22  grasses=g,leaves=l,meadows=m,paths=p, urban=u,...  None             no

# %%
X
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0            x           s         n       t    p               f
# 1            x           s         y       t    a               f
# 2            b           s         w       t    l               f
# 3            x           y         w       t    p               f
# 4            x           s         g       f    n               f
# ...        ...         ...       ...     ...  ...             ...
# 8119         k           s         n       f    n               a
# 8120         x           s         n       f    n               a
# 8121         f           s         n       f    n               a
# 8122         k           y         n       f    y               f
# 8123         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# 1               c         b          k           e  ...
# 2               c         b          n           e  ...
# 3               c         n          n           e  ...
# 4               w         b          k           t  ...
# ...           ...       ...        ...         ...  ...
# 8119            c         b          y           e  ...
# 8120            c         b          y           e  ...
# 8121            c         b          n           e  ...
# 8122            c         n          b           t  ...
# 8123            c         b          y           e  ...
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                           s                      w                      w
# 1                           s                      w                      w
# 2                           s                      w                      w
# 3                           s                      w                      w
# 4                           s                      w                      w
# ...                       ...                    ...                    ...
# 8119                        s                      o                      o
# 8120                        s                      o                      o
# 8121                        s                      o                      o
# 8122                        k                      w                      w
# 8123                        s                      o                      o
#
#      veil-type veil-color ring-number ring-type spore-print-color population  \
# 0            p          w           o         p                 k          s
# 1            p          w           o         p                 n          n
# 2            p          w           o         p                 n          n
# 3            p          w           o         p                 k          s
# 4            p          w           o         e                 n          a
# ...        ...        ...         ...       ...               ...        ...
# 8119         p          o           o         p                 b          c
# 8120         p          n           o         p                 b          v
# 8121         p          o           o         p                 b          c
# 8122         p          w           o         e                 w          v
# 8123         p          o           o         p                 o          c
#
#      habitat
# 0          u
# 1          g
# 2          m
# 3          u
# 4          g
# ...      ...
# 8119       l
# 8120       l
# 8121       l
# 8122       l
# 8123       l
#
# [8124 rows x 22 columns]

# %%
y
# Out:
#      poisonous
# 0            p
# 1            e
# 2            e
# 3            p
# 4            e
# ...        ...
# 8119         e
# 8120         e
# 8121         e
# 8122         p
# 8123         e
#
# [8124 rows x 1 columns]

# %% [markdown]
# #### Custom Logistic Regression Implementation and Evaluation with a Dummy Dataset

# %%
import numpy as np

class LogisticRegressionModel:
    def __init__(self, learning_rate=0.01, epochs=1000):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.weights = None
        self.bias = None

    def _sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        # Gradient Descent
        for _ in range(self.epochs):
            model = np.dot(X, self.weights) + self.bias
            y_predicted = self._sigmoid(model)

            error = y_predicted - y
            dw = (1 / n_samples) * np.dot(X.T, error * y_predicted * (1 - y_predicted))
            db = (1 / n_samples) * np.sum(error * y_predicted * (1 - y_predicted))

            # Update parameters
            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db

    def predict(self, X):
        linear_model = np.dot(X, self.weights) + self.bias
        y_predicted = self._sigmoid(linear_model)
        y_predicted_cls = [1 if i > 0.5 else 0 for i in y_predicted]
        return y_predicted_cls

# Usage example with a dummy dataset
np.random.seed(0)
X_dummy = np.random.rand(100, 5)  # 100 samples, 5 features each
y_dummy = np.random.randint(0, 2, 100)  # Binary targets

# Create the Logistic Regression model
log_reg_model = LogisticRegressionModel(learning_rate=0.01, epochs=1000)

# Fit the model
log_reg_model.fit(X_dummy, y_dummy)

# After fitting the model, print the updated weights and bias
print("Updated weights:", log_reg_model.weights)
print("Updated bias:", log_reg_model.bias)

# Predict using the model
y_pred_dummy = log_reg_model.predict(X_dummy)

# Evaluate the dummy predictions
accuracy_dummy = np.mean(y_pred_dummy == y_dummy)
print(f'Dummy Accuracy: {accuracy_dummy:.2f}')
# Out:
# Updated weights: [-0.09168462  0.00289753 -0.04169774  0.01148246  0.00544851]
# Updated bias: -0.057496310387814706
# Dummy Accuracy: 0.54

# %% [markdown]
# #### Applying the Logistic Regression Model to the Mushroom Dataset

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score
from ucimlrepo import fetch_ucirepo

# Fetch the dataset
mushroom = fetch_ucirepo(id=73)

# Data as pandas dataframes
X = mushroom.data.features
y = mushroom.data.targets

# Initialize LabelEncoder
encoder = LabelEncoder()

# Encode target labels
y_encoded = y.apply(encoder.fit_transform)

# Encode categorical features
X_encoded = pd.get_dummies(X, drop_first=True)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.2, random_state=42)

# Standardize features by removing the mean and scaling to unit variance
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

class LogisticRegressionModel:
    def __init__(self, learning_rate=0.01, epochs=1000):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.weights = None
        self.bias = None

    def _sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        # Gradient Descent
        for _ in range(self.epochs):
            model = np.dot(X, self.weights) + self.bias
            y_predicted = self._sigmoid(model)

            error = y_predicted - y
            dw = (1 / n_samples) * np.dot(X.T, error * y_predicted * (1 - y_predicted))
            db = (1 / n_samples) * np.sum(error * y_predicted * (1 - y_predicted))

            # Update parameters
            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db

    def predict(self, X):
        linear_model = np.dot(X, self.weights) + self.bias
        y_predicted = self._sigmoid(linear_model)
        y_predicted_cls = [1 if i > 0.5 else 0 for i in y_predicted]
        return y_predicted_cls

# Initialize the logistic regression model
log_reg_model = LogisticRegressionModel(learning_rate=0.01, epochs=1000)

# Train the model on the training data
log_reg_model.fit(X_train_scaled, y_train.values.ravel())

# Predict on the testing data
y_pred = log_reg_model.predict(X_test_scaled)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.99

# %% [markdown]
# ####  Complete Logistic Regression Workflow with the Mushroom Dataset

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score

class LogisticRegressionModel:
    def __init__(self, learning_rate=0.01, epochs=1000):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.weights = None
        self.bias = None

    def _sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        # Gradient Descent
        for _ in range(self.epochs):
            model = np.dot(X, self.weights) + self.bias
            y_predicted = self._sigmoid(model)

            error = y_predicted - y
            dw = (1 / n_samples) * np.dot(X.T, error * y_predicted * (1 - y_predicted))
            db = (1 / n_samples) * np.sum(error * y_predicted * (1 - y_predicted))

            # Update parameters
            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db

    def predict(self, X):
        linear_model = np.dot(X, self.weights) + self.bias
        y_predicted = self._sigmoid(linear_model)
        y_predicted_cls = [1 if i > 0.5 else 0 for i in y_predicted]
        return y_predicted_cls


X = mushroom.data.features
y = mushroom.data.targets

# Initialize LabelEncoder
encoder = LabelEncoder()

# Encode target labels with value between 0 and n_classes-1.
y_encoded = encoder.fit_transform(y['poisonous'])

# Encode categorical features using one-hot encoding
X_encoded = pd.get_dummies(X, drop_first=True)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.2, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train your logistic regression model
log_reg_model = LogisticRegressionModel(learning_rate=0.01, epochs=1000)
log_reg_model.fit(X_train_scaled, y_train)

# Make predictions
y_pred = log_reg_model.predict(X_test_scaled)

# Inverse transform the encoded predictions to their original label (p or e)
y_pred_labels = encoder.inverse_transform(y_pred)

# Print classification results
for i, label in enumerate(y_pred_labels):
    classification = 'poisonous' if label == 'p' else 'edible'
    print(f"Sample {i}: {classification}")
# Out:
# Sample 0: edible
# Sample 1: poisonous
# Sample 2: poisonous
# Sample 3: edible
# Sample 4: poisonous
# Sample 5: poisonous
# Sample 6: poisonous
# Sample 7: poisonous
# Sample 8: edible
# Sample 9: edible
# Sample 10: edible
# Sample 11: edible
# Sample 12: edible
# Sample 13: edible
# Sample 14: edible
# Sample 15: edible
# Sample 16: edible
# Sample 17: poisonous
# Sample 18: edible
# Sample 19: edible
# Sample 20: edible
# Sample 21: edible
# Sample 22: poisonous
# Sample 23: edible
# Sample 24: poisonous
# Sample 25: edible
# Sample 26: edible
# Sample 27: edible
# Sample 28: edible
# Sample 29: poisonous
# Sample 30: poisonous
# Sample 31: poisonous
# Sample 32: edible
# Sample 33: edible
# Sample 34: edible
# Sample 35: poisonous
# Sample 36: edible
# Sample 37: poisonous
# Sample 38: poisonous
# Sample 39: poisonous
# Sample 40: poisonous
# Sample 41: edible
# Sample 42: poisonous
# Sample 43: edible
# Sample 44: poisonous
# Sample 45: edible
# Sample 46: poisonous
# Sample 47: edible
# Sample 48: poisonous
# Sample 49: edible
# Sample 50: poisonous
# Sample 51: poisonous
# Sample 52: poisonous
# Sample 53: poisonous
# Sample 54: edible
# Sample 55: poisonous
# Sample 56: edible
# Sample 57: edible
# Sample 58: poisonous
# Sample 59: poisonous
# Sample 60: poisonous
# Sample 61: edible
# Sample 62: edible
# Sample 63: edible
# Sample 64: poisonous
# Sample 65: poisonous
# Sample 66: edible
# Sample 67: poisonous
# Sample 68: edible
# Sample 69: poisonous
# Sample 70: poisonous
# Sample 71: poisonous
# Sample 72: edible
# Sample 73: poisonous
# Sample 74: poisonous
# Sample 75: poisonous
# Sample 76: edible
# Sample 77: poisonous
# Sample 78: poisonous
# Sample 79: poisonous
# Sample 80: edible
# Sample 81: poisonous
# Sample 82: edible
# Sample 83: edible
# Sample 84: edible
# Sample 85: edible
# Sample 86: poisonous
# Sample 87: edible
# Sample 88: edible
# Sample 89: poisonous
# Sample 90: edible
# Sample 91: edible
# Sample 92: edible
# Sample 93: edible
# Sample 94: poisonous
# Sample 95: poisonous
# Sample 96: poisonous
# Sample 97: edible
# Sample 98: poisonous
# Sample 99: edible
# Sample 100: edible
# Sample 101: edible
# Sample 102: edible
# Sample 103: edible
# Sample 104: poisonous
# Sample 105: poisonous
# Sample 106: edible
# Sample 107: poisonous
# Sample 108: edible
# Sample 109: poisonous
# Sample 110: poisonous
# Sample 111: poisonous
# Sample 112: poisonous
# Sample 113: poisonous
# Sample 114: poisonous
# Sample 115: poisonous
# Sample 116: edible
# Sample 117: edible
# Sample 118: edible
# Sample 119: poisonous
# Sample 120: poisonous
# Sample 121: poisonous
# Sample 122: poisonous
# Sample 123: edible
# Sample 124: edible
# Sample 125: edible
# Sample 126: poisonous
# Sample 127: poisonous
# Sample 128: edible
# Sample 129: edible
# Sample 130: edible
# Sample 131: edible
# Sample 132: edible
# Sample 133: edible
# Sample 134: poisonous
# Sample 135: poisonous
# Sample 136: poisonous
# Sample 137: poisonous
# Sample 138: poisonous
# Sample 139: poisonous
# Sample 140: poisonous
# Sample 141: edible
# Sample 142: edible
# Sample 143: poisonous
# Sample 144: poisonous
# Sample 145: poisonous
# Sample 146: edible
# Sample 147: edible
# Sample 148: edible
# Sample 149: poisonous
# Sample 150: poisonous
# Sample 151: edible
# Sample 152: poisonous
# Sample 153: poisonous
# Sample 154: edible
# Sample 155: edible
# Sample 156: poisonous
# Sample 157: poisonous
# Sample 158: poisonous
# Sample 159: poisonous
# Sample 160: edible
# Sample 161: edible
# Sample 162: poisonous
# Sample 163: edible
# Sample 164: poisonous
# Sample 165: edible
# Sample 166: poisonous
# Sample 167: poisonous
# Sample 168: poisonous
# Sample 169: poisonous
# Sample 170: edible
# Sample 171: edible
# Sample 172: edible
# Sample 173: edible
# Sample 174: poisonous
# Sample 175: edible
# Sample 176: poisonous
# Sample 177: edible
# Sample 178: edible
# Sample 179: edible
# Sample 180: edible
# Sample 181: poisonous
# Sample 182: edible
# Sample 183: edible
# Sample 184: poisonous
# Sample 185: edible
# Sample 186: edible
# Sample 187: poisonous
# Sample 188: poisonous
# Sample 189: edible
# Sample 190: edible
# Sample 191: poisonous
# Sample 192: edible
# Sample 193: edible
# Sample 194: edible
# Sample 195: edible
# Sample 196: poisonous
# Sample 197: edible
# Sample 198: edible
# Sample 199: edible
# Sample 200: edible
# Sample 201: poisonous
# Sample 202: poisonous
# Sample 203: edible
# Sample 204: edible
# Sample 205: poisonous
# Sample 206: edible
# Sample 207: poisonous
# Sample 208: edible
# Sample 209: poisonous
# Sample 210: poisonous
# Sample 211: edible
# Sample 212: edible
# Sample 213: edible
# Sample 214: poisonous
# Sample 215: edible
# Sample 216: poisonous
# Sample 217: poisonous
# Sample 218: poisonous
# Sample 219: edible
# Sample 220: edible
# Sample 221: poisonous
# Sample 222: edible
# Sample 223: edible
# Sample 224: edible
# Sample 225: edible
# Sample 226: edible
# Sample 227: edible
# Sample 228: poisonous
# Sample 229: poisonous
# Sample 230: poisonous
# Sample 231: edible
# Sample 232: edible
# Sample 233: edible
# Sample 234: edible
# Sample 235: poisonous
# Sample 236: edible
# Sample 237: edible
# Sample 238: poisonous
# Sample 239: poisonous
# Sample 240: edible
# Sample 241: poisonous
# Sample 242: poisonous
# Sample 243: edible
# Sample 244: edible
# Sample 245: edible
# Sample 246: poisonous
# Sample 247: edible
# Sample 248: edible
# Sample 249: poisonous
# Sample 250: poisonous
# Sample 251: edible
# Sample 252: edible
# Sample 253: poisonous
# Sample 254: edible
# Sample 255: poisonous
# Sample 256: edible
# Sample 257: poisonous
# Sample 258: edible
# Sample 259: edible
# Sample 260: edible
# Sample 261: edible
# Sample 262: edible
# Sample 263: edible
# Sample 264: poisonous
# Sample 265: edible
# Sample 266: edible
# Sample 267: edible
# Sample 268: edible
# Sample 269: edible
# Sample 270: poisonous
# Sample 271: edible
# Sample 272: edible
# Sample 273: poisonous
# Sample 274: edible
# Sample 275: poisonous
# Sample 276: edible
# Sample 277: edible
# Sample 278: edible
# Sample 279: edible
# Sample 280: edible
# Sample 281: poisonous
# Sample 282: edible
# Sample 283: poisonous
# Sample 284: edible
# Sample 285: edible
# Sample 286: poisonous
# Sample 287: edible
# Sample 288: poisonous
# Sample 289: poisonous
# Sample 290: poisonous
# Sample 291: edible
# Sample 292: poisonous
# Sample 293: edible
# Sample 294: edible
# Sample 295: edible
# Sample 296: edible
# Sample 297: edible
# Sample 298: poisonous
# Sample 299: edible
# Sample 300: edible
# Sample 301: poisonous
# Sample 302: poisonous
# Sample 303: poisonous
# Sample 304: edible
# Sample 305: poisonous
# Sample 306: poisonous
# Sample 307: edible
# Sample 308: edible
# Sample 309: poisonous
# Sample 310: poisonous
# Sample 311: edible
# Sample 312: poisonous
# Sample 313: edible
# Sample 314: edible
# Sample 315: poisonous
# Sample 316: edible
# Sample 317: poisonous
# Sample 318: poisonous
# Sample 319: poisonous
# Sample 320: edible
# Sample 321: poisonous
# Sample 322: edible
# Sample 323: poisonous
# Sample 324: poisonous
# Sample 325: poisonous
# Sample 326: poisonous
# Sample 327: poisonous
# Sample 328: poisonous
# Sample 329: poisonous
# Sample 330: edible
# Sample 331: edible
# Sample 332: poisonous
# Sample 333: poisonous
# Sample 334: edible
# Sample 335: poisonous
# Sample 336: poisonous
# Sample 337: poisonous
# Sample 338: edible
# Sample 339: poisonous
# Sample 340: edible
# Sample 341: edible
# Sample 342: edible
# Sample 343: poisonous
# Sample 344: edible
# Sample 345: poisonous
# Sample 346: poisonous
# Sample 347: edible
# Sample 348: edible
# Sample 349: poisonous
# Sample 350: edible
# Sample 351: edible
# Sample 352: edible
# Sample 353: edible
# Sample 354: edible
# Sample 355: poisonous
# Sample 356: edible
# Sample 357: edible
# Sample 358: poisonous
# Sample 359: edible
# Sample 360: edible
# Sample 361: poisonous
# Sample 362: poisonous
# Sample 363: poisonous
# Sample 364: edible
# Sample 365: edible
# Sample 366: poisonous
# Sample 367: poisonous
# Sample 368: poisonous
# Sample 369: poisonous
# Sample 370: edible
# Sample 371: edible
# Sample 372: edible
# Sample 373: edible
# Sample 374: poisonous
# Sample 375: poisonous
# Sample 376: edible
# Sample 377: poisonous
# Sample 378: poisonous
# Sample 379: edible
# Sample 380: edible
# Sample 381: edible
# Sample 382: poisonous
# Sample 383: poisonous
# Sample 384: poisonous
# Sample 385: edible
# Sample 386: poisonous
# Sample 387: poisonous
# Sample 388: poisonous
# Sample 389: poisonous
# Sample 390: poisonous
# Sample 391: poisonous
# Sample 392: edible
# Sample 393: poisonous
# Sample 394: poisonous
# Sample 395: edible
# Sample 396: poisonous
# Sample 397: edible
# Sample 398: poisonous
# Sample 399: poisonous
# Sample 400: edible
# Sample 401: edible
# Sample 402: edible
# Sample 403: edible
# Sample 404: poisonous
# Sample 405: poisonous
# Sample 406: poisonous
# Sample 407: edible
# Sample 408: edible
# Sample 409: poisonous
# Sample 410: poisonous
# Sample 411: edible
# Sample 412: poisonous
# Sample 413: edible
# Sample 414: poisonous
# Sample 415: poisonous
# Sample 416: edible
# Sample 417: poisonous
# Sample 418: edible
# Sample 419: poisonous
# Sample 420: edible
# Sample 421: poisonous
# Sample 422: edible
# Sample 423: edible
# Sample 424: poisonous
# Sample 425: edible
# Sample 426: poisonous
# Sample 427: poisonous
# Sample 428: edible
# Sample 429: poisonous
# Sample 430: poisonous
# Sample 431: poisonous
# Sample 432: edible
# Sample 433: poisonous
# Sample 434: edible
# Sample 435: poisonous
# Sample 436: edible
# Sample 437: poisonous
# Sample 438: poisonous
# Sample 439: edible
# Sample 440: edible
# Sample 441: edible
# Sample 442: poisonous
# Sample 443: poisonous
# Sample 444: poisonous
# Sample 445: poisonous
# Sample 446: poisonous
# Sample 447: poisonous
# Sample 448: poisonous
# Sample 449: poisonous
# Sample 450: poisonous
# Sample 451: poisonous
# Sample 452: poisonous
# Sample 453: edible
# Sample 454: edible
# Sample 455: edible
# Sample 456: poisonous
# Sample 457: edible
# Sample 458: edible
# Sample 459: edible
# Sample 460: poisonous
# Sample 461: poisonous
# Sample 462: poisonous
# Sample 463: poisonous
# Sample 464: poisonous
# Sample 465: poisonous
# Sample 466: edible
# Sample 467: edible
# Sample 468: poisonous
# Sample 469: edible
# Sample 470: poisonous
# Sample 471: edible
# Sample 472: edible
# Sample 473: poisonous
# Sample 474: poisonous
# Sample 475: edible
# Sample 476: edible
# Sample 477: edible
# Sample 478: edible
# Sample 479: poisonous
# Sample 480: poisonous
# Sample 481: edible
# Sample 482: edible
# Sample 483: poisonous
# Sample 484: poisonous
# Sample 485: poisonous
# Sample 486: edible
# Sample 487: edible
# Sample 488: edible
# Sample 489: edible
# Sample 490: edible
# Sample 491: edible
# Sample 492: edible
# Sample 493: edible
# Sample 494: poisonous
# Sample 495: edible
# Sample 496: edible
# Sample 497: edible
# Sample 498: poisonous
# Sample 499: poisonous
# Sample 500: edible
# Sample 501: poisonous
# Sample 502: poisonous
# Sample 503: poisonous
# Sample 504: poisonous
# Sample 505: edible
# Sample 506: edible
# Sample 507: poisonous
# Sample 508: edible
# Sample 509: edible
# Sample 510: edible
# Sample 511: edible
# Sample 512: poisonous
# Sample 513: edible
# Sample 514: edible
# Sample 515: poisonous
# Sample 516: edible
# Sample 517: poisonous
# Sample 518: edible
# Sample 519: edible
# Sample 520: poisonous
# Sample 521: edible
# Sample 522: edible
# Sample 523: poisonous
# Sample 524: edible
# Sample 525: poisonous
# Sample 526: poisonous
# Sample 527: edible
# Sample 528: edible
# Sample 529: edible
# Sample 530: poisonous
# Sample 531: poisonous
# Sample 532: edible
# Sample 533: edible
# Sample 534: poisonous
# Sample 535: poisonous
# Sample 536: poisonous
# Sample 537: poisonous
# Sample 538: edible
# Sample 539: edible
# Sample 540: poisonous
# Sample 541: poisonous
# Sample 542: edible
# Sample 543: poisonous
# Sample 544: edible
# Sample 545: edible
# Sample 546: edible
# Sample 547: edible
# Sample 548: poisonous
# Sample 549: poisonous
# Sample 550: poisonous
# Sample 551: poisonous
# Sample 552: poisonous
# Sample 553: edible
# Sample 554: poisonous
# Sample 555: edible
# Sample 556: poisonous
# Sample 557: poisonous
# Sample 558: poisonous
# Sample 559: edible
# Sample 560: edible
# Sample 561: edible
# Sample 562: poisonous
# Sample 563: poisonous
# Sample 564: poisonous
# Sample 565: edible
# Sample 566: poisonous
# Sample 567: edible
# Sample 568: edible
# Sample 569: edible
# Sample 570: edible
# Sample 571: edible
# Sample 572: edible
# Sample 573: edible
# Sample 574: edible
# Sample 575: poisonous
# Sample 576: edible
# Sample 577: poisonous
# Sample 578: poisonous
# Sample 579: poisonous
# Sample 580: poisonous
# Sample 581: edible
# Sample 582: poisonous
# Sample 583: edible
# Sample 584: poisonous
# Sample 585: edible
# Sample 586: poisonous
# Sample 587: edible
# Sample 588: edible
# Sample 589: edible
# Sample 590: edible
# Sample 591: edible
# Sample 592: edible
# Sample 593: edible
# Sample 594: edible
# Sample 595: poisonous
# Sample 596: edible
# Sample 597: poisonous
# Sample 598: edible
# Sample 599: edible
# Sample 600: edible
# Sample 601: edible
# Sample 602: poisonous
# Sample 603: edible
# Sample 604: edible
# Sample 605: poisonous
# Sample 606: poisonous
# Sample 607: poisonous
# Sample 608: poisonous
# Sample 609: poisonous
# Sample 610: poisonous
# Sample 611: edible
# Sample 612: poisonous
# Sample 613: poisonous
# Sample 614: edible
# Sample 615: edible
# Sample 616: poisonous
# Sample 617: edible
# Sample 618: poisonous
# Sample 619: edible
# Sample 620: poisonous
# Sample 621: poisonous
# Sample 622: poisonous
# Sample 623: edible
# Sample 624: edible
# Sample 625: poisonous
# Sample 626: edible
# Sample 627: edible
# Sample 628: edible
# Sample 629: poisonous
# Sample 630: edible
# Sample 631: poisonous
# Sample 632: edible
# Sample 633: poisonous
# Sample 634: poisonous
# Sample 635: edible
# Sample 636: poisonous
# Sample 637: poisonous
# Sample 638: edible
# Sample 639: edible
# Sample 640: edible
# Sample 641: edible
# Sample 642: edible
# Sample 643: edible
# Sample 644: edible
# Sample 645: poisonous
# Sample 646: edible
# Sample 647: poisonous
# Sample 648: edible
# Sample 649: poisonous
# Sample 650: poisonous
# Sample 651: poisonous
# Sample 652: edible
# Sample 653: edible
# Sample 654: edible
# Sample 655: edible
# Sample 656: edible
# Sample 657: poisonous
# Sample 658: poisonous
# Sample 659: poisonous
# Sample 660: edible
# Sample 661: poisonous
# Sample 662: edible
# Sample 663: edible
# Sample 664: edible
# Sample 665: edible
# Sample 666: poisonous
# Sample 667: poisonous
# Sample 668: poisonous
# Sample 669: edible
# Sample 670: edible
# Sample 671: edible
# Sample 672: edible
# Sample 673: edible
# Sample 674: edible
# Sample 675: poisonous
# Sample 676: edible
# Sample 677: edible
# Sample 678: edible
# Sample 679: edible
# Sample 680: poisonous
# Sample 681: poisonous
# Sample 682: edible
# Sample 683: edible
# Sample 684: poisonous
# Sample 685: edible
# Sample 686: poisonous
# Sample 687: edible
# Sample 688: poisonous
# Sample 689: edible
# Sample 690: poisonous
# Sample 691: edible
# Sample 692: edible
# Sample 693: poisonous
# Sample 694: edible
# Sample 695: edible
# Sample 696: poisonous
# Sample 697: edible
# Sample 698: edible
# Sample 699: edible
# Sample 700: poisonous
# Sample 701: edible
# Sample 702: edible
# Sample 703: poisonous
# Sample 704: poisonous
# Sample 705: edible
# Sample 706: edible
# Sample 707: poisonous
# Sample 708: poisonous
# Sample 709: poisonous
# Sample 710: edible
# Sample 711: poisonous
# Sample 712: edible
# Sample 713: edible
# Sample 714: poisonous
# Sample 715: poisonous
# Sample 716: edible
# Sample 717: poisonous
# Sample 718: edible
# Sample 719: edible
# Sample 720: poisonous
# Sample 721: poisonous
# Sample 722: edible
# Sample 723: edible
# Sample 724: poisonous
# Sample 725: edible
# Sample 726: poisonous
# Sample 727: poisonous
# Sample 728: edible
# Sample 729: poisonous
# Sample 730: edible
# Sample 731: poisonous
# Sample 732: edible
# Sample 733: edible
# Sample 734: edible
# Sample 735: edible
# Sample 736: poisonous
# Sample 737: edible
# Sample 738: poisonous
# Sample 739: edible
# Sample 740: poisonous
# Sample 741: edible
# Sample 742: edible
# Sample 743: edible
# Sample 744: poisonous
# Sample 745: edible
# Sample 746: edible
# Sample 747: edible
# Sample 748: poisonous
# Sample 749: poisonous
# Sample 750: edible
# Sample 751: edible
# Sample 752: edible
# Sample 753: edible
# Sample 754: poisonous
# Sample 755: poisonous
# Sample 756: edible
# Sample 757: poisonous
# Sample 758: poisonous
# Sample 759: edible
# Sample 760: edible
# Sample 761: edible
# Sample 762: poisonous
# Sample 763: edible
# Sample 764: edible
# Sample 765: poisonous
# Sample 766: edible
# Sample 767: poisonous
# Sample 768: edible
# Sample 769: edible
# Sample 770: poisonous
# Sample 771: poisonous
# Sample 772: poisonous
# Sample 773: edible
# Sample 774: edible
# Sample 775: poisonous
# Sample 776: edible
# Sample 777: edible
# Sample 778: edible
# Sample 779: poisonous
# Sample 780: edible
# Sample 781: edible
# Sample 782: poisonous
# Sample 783: poisonous
# Sample 784: edible
# Sample 785: poisonous
# Sample 786: poisonous
# Sample 787: poisonous
# Sample 788: edible
# Sample 789: poisonous
# Sample 790: poisonous
# Sample 791: edible
# Sample 792: edible
# Sample 793: edible
# Sample 794: edible
# Sample 795: edible
# Sample 796: edible
# Sample 797: poisonous
# Sample 798: poisonous
# Sample 799: edible
# Sample 800: edible
# Sample 801: edible
# Sample 802: poisonous
# Sample 803: edible
# Sample 804: poisonous
# Sample 805: edible
# Sample 806: edible
# Sample 807: poisonous
# Sample 808: edible
# Sample 809: poisonous
# Sample 810: poisonous
# Sample 811: poisonous
# Sample 812: poisonous
# Sample 813: poisonous
# Sample 814: poisonous
# Sample 815: edible
# Sample 816: poisonous
# Sample 817: poisonous
# Sample 818: poisonous
# Sample 819: edible
# Sample 820: edible
# Sample 821: edible
# Sample 822: edible
# Sample 823: poisonous
# Sample 824: edible
# Sample 825: poisonous
# Sample 826: edible
# Sample 827: edible
# Sample 828: edible
# Sample 829: poisonous
# Sample 830: edible
# Sample 831: edible
# Sample 832: edible
# Sample 833: poisonous
# Sample 834: poisonous
# Sample 835: poisonous
# Sample 836: poisonous
# Sample 837: poisonous
# Sample 838: edible
# Sample 839: edible
# Sample 840: edible
# Sample 841: poisonous
# Sample 842: poisonous
# Sample 843: edible
# Sample 844: edible
# Sample 845: edible
# Sample 846: edible
# Sample 847: edible
# Sample 848: poisonous
# Sample 849: poisonous
# Sample 850: edible
# Sample 851: edible
# Sample 852: edible
# Sample 853: poisonous
# Sample 854: poisonous
# Sample 855: edible
# Sample 856: poisonous
# Sample 857: edible
# Sample 858: poisonous
# Sample 859: edible
# Sample 860: poisonous
# Sample 861: poisonous
# Sample 862: poisonous
# Sample 863: poisonous
# Sample 864: edible
# Sample 865: edible
# Sample 866: poisonous
# Sample 867: poisonous
# Sample 868: edible
# Sample 869: edible
# Sample 870: edible
# Sample 871: edible
# Sample 872: edible
# Sample 873: edible
# Sample 874: poisonous
# Sample 875: poisonous
# Sample 876: edible
# Sample 877: poisonous
# Sample 878: edible
# Sample 879: poisonous
# Sample 880: poisonous
# Sample 881: poisonous
# Sample 882: poisonous
# Sample 883: edible
# Sample 884: poisonous
# Sample 885: edible
# Sample 886: poisonous
# Sample 887: poisonous
# Sample 888: edible
# Sample 889: poisonous
# Sample 890: edible
# Sample 891: poisonous
# Sample 892: poisonous
# Sample 893: edible
# Sample 894: edible
# Sample 895: edible
# Sample 896: poisonous
# Sample 897: poisonous
# Sample 898: poisonous
# Sample 899: poisonous
# Sample 900: poisonous
# Sample 901: edible
# Sample 902: edible
# Sample 903: edible
# Sample 904: edible
# Sample 905: edible
# Sample 906: poisonous
# Sample 907: poisonous
# Sample 908: edible
# Sample 909: edible
# Sample 910: edible
# Sample 911: poisonous
# Sample 912: poisonous
# Sample 913: poisonous
# Sample 914: poisonous
# Sample 915: edible
# Sample 916: poisonous
# Sample 917: poisonous
# Sample 918: edible
# Sample 919: poisonous
# Sample 920: poisonous
# Sample 921: edible
# Sample 922: poisonous
# Sample 923: edible
# Sample 924: edible
# Sample 925: poisonous
# Sample 926: edible
# Sample 927: poisonous
# Sample 928: poisonous
# Sample 929: edible
# Sample 930: poisonous
# Sample 931: poisonous
# Sample 932: poisonous
# Sample 933: edible
# Sample 934: poisonous
# Sample 935: edible
# Sample 936: poisonous
# Sample 937: poisonous
# Sample 938: edible
# Sample 939: poisonous
# Sample 940: edible
# Sample 941: poisonous
# Sample 942: edible
# Sample 943: edible
# Sample 944: poisonous
# Sample 945: poisonous
# Sample 946: poisonous
# Sample 947: poisonous
# Sample 948: poisonous
# Sample 949: poisonous
# Sample 950: poisonous
# Sample 951: edible
# Sample 952: edible
# Sample 953: edible
# Sample 954: edible
# Sample 955: edible
# Sample 956: edible
# Sample 957: edible
# Sample 958: edible
# Sample 959: edible
# Sample 960: edible
# Sample 961: poisonous
# Sample 962: edible
# Sample 963: edible
# Sample 964: poisonous
# Sample 965: edible
# Sample 966: poisonous
# Sample 967: edible
# Sample 968: edible
# Sample 969: poisonous
# Sample 970: poisonous
# Sample 971: poisonous
# Sample 972: poisonous
# Sample 973: poisonous
# Sample 974: poisonous
# Sample 975: poisonous
# Sample 976: poisonous
# Sample 977: poisonous
# Sample 978: edible
# Sample 979: edible
# Sample 980: edible
# Sample 981: edible
# Sample 982: poisonous
# Sample 983: edible
# Sample 984: poisonous
# Sample 985: edible
# Sample 986: edible
# Sample 987: poisonous
# Sample 988: edible
# Sample 989: poisonous
# Sample 990: poisonous
# Sample 991: edible
# Sample 992: edible
# Sample 993: poisonous
# Sample 994: edible
# Sample 995: poisonous
# Sample 996: poisonous
# Sample 997: edible
# Sample 998: edible
# Sample 999: edible
# Sample 1000: poisonous
# Sample 1001: edible
# Sample 1002: edible
# Sample 1003: edible
# Sample 1004: poisonous
# Sample 1005: edible
# Sample 1006: edible
# Sample 1007: poisonous
# Sample 1008: poisonous
# Sample 1009: edible
# Sample 1010: poisonous
# Sample 1011: edible
# Sample 1012: poisonous
# Sample 1013: edible
# Sample 1014: poisonous
# Sample 1015: poisonous
# Sample 1016: edible
# Sample 1017: edible
# Sample 1018: poisonous
# Sample 1019: edible
# Sample 1020: poisonous
# Sample 1021: poisonous
# Sample 1022: edible
# Sample 1023: poisonous
# Sample 1024: poisonous
# Sample 1025: edible
# Sample 1026: edible
# Sample 1027: edible
# Sample 1028: poisonous
# Sample 1029: poisonous
# Sample 1030: edible
# Sample 1031: edible
# Sample 1032: edible
# Sample 1033: edible
# Sample 1034: edible
# Sample 1035: edible
# Sample 1036: poisonous
# Sample 1037: poisonous
# Sample 1038: poisonous
# Sample 1039: edible
# Sample 1040: edible
# Sample 1041: edible
# Sample 1042: edible
# Sample 1043: poisonous
# Sample 1044: poisonous
# Sample 1045: edible
# Sample 1046: edible
# Sample 1047: edible
# Sample 1048: edible
# Sample 1049: poisonous
# Sample 1050: poisonous
# Sample 1051: poisonous
# Sample 1052: edible
# Sample 1053: poisonous
# Sample 1054: poisonous
# Sample 1055: edible
# Sample 1056: poisonous
# Sample 1057: edible
# Sample 1058: poisonous
# Sample 1059: edible
# Sample 1060: poisonous
# Sample 1061: poisonous
# Sample 1062: poisonous
# Sample 1063: poisonous
# Sample 1064: edible
# Sample 1065: edible
# Sample 1066: poisonous
# Sample 1067: edible
# Sample 1068: poisonous
# Sample 1069: edible
# Sample 1070: poisonous
# Sample 1071: poisonous
# Sample 1072: poisonous
# Sample 1073: edible
# Sample 1074: edible
# Sample 1075: edible
# Sample 1076: edible
# Sample 1077: poisonous
# Sample 1078: edible
# Sample 1079: edible
# Sample 1080: poisonous
# Sample 1081: poisonous
# Sample 1082: poisonous
# Sample 1083: edible
# Sample 1084: edible
# Sample 1085: edible
# Sample 1086: poisonous
# Sample 1087: poisonous
# Sample 1088: poisonous
# Sample 1089: poisonous
# Sample 1090: edible
# Sample 1091: edible
# Sample 1092: poisonous
# Sample 1093: edible
# Sample 1094: poisonous
# Sample 1095: edible
# Sample 1096: edible
# Sample 1097: edible
# Sample 1098: edible
# Sample 1099: edible
# Sample 1100: poisonous
# Sample 1101: poisonous
# Sample 1102: poisonous
# Sample 1103: edible
# Sample 1104: edible
# Sample 1105: edible
# Sample 1106: poisonous
# Sample 1107: poisonous
# Sample 1108: poisonous
# Sample 1109: poisonous
# Sample 1110: edible
# Sample 1111: poisonous
# Sample 1112: poisonous
# Sample 1113: poisonous
# Sample 1114: edible
# Sample 1115: poisonous
# Sample 1116: edible
# Sample 1117: poisonous
# Sample 1118: edible
# Sample 1119: edible
# Sample 1120: edible
# Sample 1121: poisonous
# Sample 1122: poisonous
# Sample 1123: edible
# Sample 1124: poisonous
# Sample 1125: edible
# Sample 1126: edible
# Sample 1127: poisonous
# Sample 1128: poisonous
# Sample 1129: poisonous
# Sample 1130: poisonous
# Sample 1131: edible
# Sample 1132: edible
# Sample 1133: poisonous
# Sample 1134: edible
# Sample 1135: edible
# Sample 1136: poisonous
# Sample 1137: edible
# Sample 1138: poisonous
# Sample 1139: edible
# Sample 1140: edible
# Sample 1141: edible
# Sample 1142: poisonous
# Sample 1143: edible
# Sample 1144: edible
# Sample 1145: edible
# Sample 1146: poisonous
# Sample 1147: poisonous
# Sample 1148: edible
# Sample 1149: poisonous
# Sample 1150: poisonous
# Sample 1151: poisonous
# Sample 1152: poisonous
# Sample 1153: poisonous
# Sample 1154: edible
# Sample 1155: poisonous
# Sample 1156: poisonous
# Sample 1157: poisonous
# Sample 1158: poisonous
# Sample 1159: edible
# Sample 1160: edible
# Sample 1161: poisonous
# Sample 1162: edible
# Sample 1163: edible
# Sample 1164: edible
# Sample 1165: edible
# Sample 1166: poisonous
# Sample 1167: poisonous
# Sample 1168: edible
# Sample 1169: edible
# Sample 1170: edible
# Sample 1171: poisonous
# Sample 1172: poisonous
# Sample 1173: edible
# Sample 1174: edible
# Sample 1175: edible
# Sample 1176: poisonous
# Sample 1177: poisonous
# Sample 1178: poisonous
# Sample 1179: poisonous
# Sample 1180: poisonous
# Sample 1181: poisonous
# Sample 1182: edible
# Sample 1183: edible
# Sample 1184: poisonous
# Sample 1185: poisonous
# Sample 1186: poisonous
# Sample 1187: edible
# Sample 1188: edible
# Sample 1189: poisonous
# Sample 1190: poisonous
# Sample 1191: poisonous
# Sample 1192: edible
# Sample 1193: poisonous
# Sample 1194: poisonous
# Sample 1195: edible
# Sample 1196: edible
# Sample 1197: edible
# Sample 1198: edible
# Sample 1199: poisonous
# Sample 1200: poisonous
# Sample 1201: poisonous
# Sample 1202: poisonous
# Sample 1203: edible
# Sample 1204: edible
# Sample 1205: poisonous
# Sample 1206: edible
# Sample 1207: edible
# Sample 1208: poisonous
# Sample 1209: edible
# Sample 1210: edible
# Sample 1211: poisonous
# Sample 1212: edible
# Sample 1213: poisonous
# Sample 1214: poisonous
# Sample 1215: poisonous
# Sample 1216: edible
# Sample 1217: edible
# Sample 1218: edible
# Sample 1219: edible
# Sample 1220: poisonous
# Sample 1221: poisonous
# Sample 1222: poisonous
# Sample 1223: edible
# Sample 1224: edible
# Sample 1225: edible
# Sample 1226: poisonous
# Sample 1227: edible
# Sample 1228: edible
# Sample 1229: edible
# Sample 1230: poisonous
# Sample 1231: poisonous
# Sample 1232: poisonous
# Sample 1233: edible
# Sample 1234: edible
# Sample 1235: edible
# Sample 1236: poisonous
# Sample 1237: edible
# Sample 1238: edible
# Sample 1239: edible
# Sample 1240: edible
# Sample 1241: poisonous
# Sample 1242: poisonous
# Sample 1243: poisonous
# Sample 1244: edible
# Sample 1245: edible
# Sample 1246: edible
# Sample 1247: edible
# Sample 1248: poisonous
# Sample 1249: edible
# Sample 1250: poisonous
# Sample 1251: edible
# Sample 1252: poisonous
# Sample 1253: poisonous
# Sample 1254: edible
# Sample 1255: edible
# Sample 1256: poisonous
# Sample 1257: edible
# Sample 1258: poisonous
# Sample 1259: edible
# Sample 1260: edible
# Sample 1261: poisonous
# Sample 1262: poisonous
# Sample 1263: edible
# Sample 1264: poisonous
# Sample 1265: poisonous
# Sample 1266: poisonous
# Sample 1267: poisonous
# Sample 1268: poisonous
# Sample 1269: poisonous
# Sample 1270: edible
# Sample 1271: edible
# Sample 1272: edible
# Sample 1273: poisonous
# Sample 1274: poisonous
# Sample 1275: edible
# Sample 1276: poisonous
# Sample 1277: poisonous
# Sample 1278: edible
# Sample 1279: edible
# Sample 1280: poisonous
# Sample 1281: poisonous
# Sample 1282: edible
# Sample 1283: poisonous
# Sample 1284: poisonous
# Sample 1285: poisonous
# Sample 1286: edible
# Sample 1287: poisonous
# Sample 1288: edible
# Sample 1289: edible
# Sample 1290: poisonous
# Sample 1291: edible
# Sample 1292: edible
# Sample 1293: edible
# Sample 1294: edible
# Sample 1295: poisonous
# Sample 1296: edible
# Sample 1297: poisonous
# Sample 1298: edible
# Sample 1299: poisonous
# Sample 1300: poisonous
# Sample 1301: edible
# Sample 1302: edible
# Sample 1303: edible
# Sample 1304: poisonous
# Sample 1305: edible
# Sample 1306: poisonous
# Sample 1307: edible
# Sample 1308: edible
# Sample 1309: poisonous
# Sample 1310: poisonous
# Sample 1311: edible
# Sample 1312: poisonous
# Sample 1313: edible
# Sample 1314: edible
# Sample 1315: edible
# Sample 1316: poisonous
# Sample 1317: edible
# Sample 1318: edible
# Sample 1319: edible
# Sample 1320: poisonous
# Sample 1321: poisonous
# Sample 1322: edible
# Sample 1323: poisonous
# Sample 1324: poisonous
# Sample 1325: poisonous
# Sample 1326: poisonous
# Sample 1327: edible
# Sample 1328: edible
# Sample 1329: edible
# Sample 1330: edible
# Sample 1331: poisonous
# Sample 1332: poisonous
# Sample 1333: edible
# Sample 1334: poisonous
# Sample 1335: edible
# Sample 1336: poisonous
# Sample 1337: edible
# Sample 1338: edible
# Sample 1339: edible
# Sample 1340: edible
# Sample 1341: edible
# Sample 1342: poisonous
# Sample 1343: poisonous
# Sample 1344: edible
# Sample 1345: poisonous
# Sample 1346: edible
# Sample 1347: edible
# Sample 1348: edible
# Sample 1349: edible
# Sample 1350: edible
# Sample 1351: poisonous
# Sample 1352: poisonous
# Sample 1353: edible
# Sample 1354: edible
# Sample 1355: edible
# Sample 1356: edible
# Sample 1357: poisonous
# Sample 1358: edible
# Sample 1359: poisonous
# Sample 1360: edible
# Sample 1361: edible
# Sample 1362: poisonous
# Sample 1363: edible
# Sample 1364: poisonous
# Sample 1365: poisonous
# Sample 1366: poisonous
# Sample 1367: edible
# Sample 1368: poisonous
# Sample 1369: edible
# Sample 1370: poisonous
# Sample 1371: edible
# Sample 1372: poisonous
# Sample 1373: edible
# Sample 1374: poisonous
# Sample 1375: poisonous
# Sample 1376: edible
# Sample 1377: poisonous
# Sample 1378: poisonous
# Sample 1379: edible
# Sample 1380: poisonous
# Sample 1381: poisonous
# Sample 1382: poisonous
# Sample 1383: edible
# Sample 1384: poisonous
# Sample 1385: poisonous
# Sample 1386: poisonous
# Sample 1387: edible
# Sample 1388: poisonous
# Sample 1389: poisonous
# Sample 1390: poisonous
# Sample 1391: poisonous
# Sample 1392: edible
# Sample 1393: edible
# Sample 1394: edible
# Sample 1395: edible
# Sample 1396: poisonous
# Sample 1397: poisonous
# Sample 1398: poisonous
# Sample 1399: poisonous
# Sample 1400: poisonous
# Sample 1401: poisonous
# Sample 1402: poisonous
# Sample 1403: edible
# Sample 1404: poisonous
# Sample 1405: poisonous
# Sample 1406: edible
# Sample 1407: edible
# Sample 1408: edible
# Sample 1409: edible
# Sample 1410: poisonous
# Sample 1411: edible
# Sample 1412: poisonous
# Sample 1413: poisonous
# Sample 1414: poisonous
# Sample 1415: edible
# Sample 1416: edible
# Sample 1417: poisonous
# Sample 1418: edible
# Sample 1419: poisonous
# Sample 1420: poisonous
# Sample 1421: edible
# Sample 1422: poisonous
# Sample 1423: edible
# Sample 1424: poisonous
# Sample 1425: edible
# Sample 1426: edible
# Sample 1427: edible
# Sample 1428: poisonous
# Sample 1429: edible
# Sample 1430: edible
# Sample 1431: edible
# Sample 1432: poisonous
# Sample 1433: edible
# Sample 1434: poisonous
# Sample 1435: edible
# Sample 1436: edible
# Sample 1437: poisonous
# Sample 1438: edible
# Sample 1439: edible
# Sample 1440: edible
# Sample 1441: edible
# Sample 1442: poisonous
# Sample 1443: edible
# Sample 1444: poisonous
# Sample 1445: poisonous
# Sample 1446: edible
# Sample 1447: edible
# Sample 1448: poisonous
# Sample 1449: edible
# Sample 1450: edible
# Sample 1451: edible
# Sample 1452: edible
# Sample 1453: poisonous
# Sample 1454: edible
# Sample 1455: poisonous
# Sample 1456: poisonous
# Sample 1457: poisonous
# Sample 1458: poisonous
# Sample 1459: poisonous
# Sample 1460: poisonous
# Sample 1461: edible
# Sample 1462: poisonous
# Sample 1463: edible
# Sample 1464: poisonous
# Sample 1465: poisonous
# Sample 1466: edible
# Sample 1467: poisonous
# Sample 1468: poisonous
# Sample 1469: edible
# Sample 1470: poisonous
# Sample 1471: edible
# Sample 1472: poisonous
# Sample 1473: edible
# Sample 1474: edible
# Sample 1475: poisonous
# Sample 1476: edible
# Sample 1477: poisonous
# Sample 1478: poisonous
# Sample 1479: edible
# Sample 1480: edible
# Sample 1481: poisonous
# Sample 1482: edible
# Sample 1483: poisonous
# Sample 1484: poisonous
# Sample 1485: poisonous
# Sample 1486: edible
# Sample 1487: edible
# Sample 1488: poisonous
# Sample 1489: poisonous
# Sample 1490: edible
# Sample 1491: edible
# Sample 1492: edible
# Sample 1493: poisonous
# Sample 1494: poisonous
# Sample 1495: edible
# Sample 1496: poisonous
# Sample 1497: edible
# Sample 1498: edible
# Sample 1499: edible
# Sample 1500: edible
# Sample 1501: edible
# Sample 1502: edible
# Sample 1503: edible
# Sample 1504: poisonous
# Sample 1505: poisonous
# Sample 1506: edible
# Sample 1507: poisonous
# Sample 1508: poisonous
# Sample 1509: edible
# Sample 1510: poisonous
# Sample 1511: poisonous
# Sample 1512: poisonous
# Sample 1513: poisonous
# Sample 1514: poisonous
# Sample 1515: edible
# Sample 1516: poisonous
# Sample 1517: edible
# Sample 1518: edible
# Sample 1519: poisonous
# Sample 1520: poisonous
# Sample 1521: edible
# Sample 1522: edible
# Sample 1523: poisonous
# Sample 1524: poisonous
# Sample 1525: edible
# Sample 1526: edible
# Sample 1527: edible
# Sample 1528: edible
# Sample 1529: edible
# Sample 1530: poisonous
# Sample 1531: poisonous
# Sample 1532: poisonous
# Sample 1533: poisonous
# Sample 1534: poisonous
# Sample 1535: edible
# Sample 1536: poisonous
# Sample 1537: edible
# Sample 1538: edible
# Sample 1539: edible
# Sample 1540: edible
# Sample 1541: edible
# Sample 1542: poisonous
# Sample 1543: edible
# Sample 1544: edible
# Sample 1545: edible
# Sample 1546: poisonous
# Sample 1547: edible
# Sample 1548: edible
# Sample 1549: edible
# Sample 1550: edible
# Sample 1551: edible
# Sample 1552: poisonous
# Sample 1553: poisonous
# Sample 1554: poisonous
# Sample 1555: edible
# Sample 1556: poisonous
# Sample 1557: edible
# Sample 1558: edible
# Sample 1559: edible
# Sample 1560: poisonous
# Sample 1561: poisonous
# Sample 1562: poisonous
# Sample 1563: poisonous
# Sample 1564: poisonous
# Sample 1565: edible
# Sample 1566: edible
# Sample 1567: edible
# Sample 1568: edible
# Sample 1569: edible
# Sample 1570: edible
# Sample 1571: edible
# Sample 1572: edible
# Sample 1573: edible
# Sample 1574: edible
# Sample 1575: poisonous
# Sample 1576: poisonous
# Sample 1577: poisonous
# Sample 1578: edible
# Sample 1579: poisonous
# Sample 1580: poisonous
# Sample 1581: edible
# Sample 1582: edible
# Sample 1583: poisonous
# Sample 1584: poisonous
# Sample 1585: edible
# Sample 1586: edible
# Sample 1587: poisonous
# Sample 1588: poisonous
# Sample 1589: edible
# Sample 1590: poisonous
# Sample 1591: edible
# Sample 1592: edible
# Sample 1593: poisonous
# Sample 1594: poisonous
# Sample 1595: poisonous
# Sample 1596: edible
# Sample 1597: poisonous
# Sample 1598: edible
# Sample 1599: poisonous
# Sample 1600: edible
# Sample 1601: poisonous
# Sample 1602: poisonous
# Sample 1603: poisonous
# Sample 1604: poisonous
# Sample 1605: poisonous
# Sample 1606: edible
# Sample 1607: poisonous
# Sample 1608: edible
# Sample 1609: poisonous
# Sample 1610: poisonous
# Sample 1611: poisonous
# Sample 1612: edible
# Sample 1613: edible
# Sample 1614: edible
# Sample 1615: poisonous
# Sample 1616: poisonous
# Sample 1617: poisonous
# Sample 1618: poisonous
# Sample 1619: poisonous
# Sample 1620: poisonous
# Sample 1621: edible
# Sample 1622: poisonous
# Sample 1623: poisonous
# Sample 1624: poisonous
